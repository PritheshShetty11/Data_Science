# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4, 5])  # 1D array

arr1.dtype
# Out:
# dtype('int64')

# %%
arr1.astype("float64")
# Out:
# array([1., 2., 3., 4., 5.])

# %%
arr2 = np.array([1, 2, 3, 4, 5],dtype="float32")

# %%
arr2.dtype
# Out:
# dtype('float32')

# %%
arr2
# Out:
# array([1., 2., 3., 4., 5.], dtype=float32)

# %%
b=arr2.astype("int32")

# %%
b
# Out:
# array([1, 2, 3, 4, 5], dtype=int32)

# %%
arr3 = np.array([1, 2, 3, 4, 5],dtype="int64")

# %%
arr3.dtype
# Out:
# dtype('int64')

# %%
ar=arr3.astype("int32")

# %%
ar.nbytes
# Out:
# 20
