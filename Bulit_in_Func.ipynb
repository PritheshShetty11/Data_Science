# %%
import numpy as np

arr1 = np.array([2, 2, 1, 4, 5,5])

# %%
np.mean(arr1)
# Out:
# np.float64(2.8)

# %%
np.max(arr1)
# Out:
# np.int64(5)

# %%
np.min(arr1)
# Out:
# np.int64(1)

# %%
np.std(arr1)
# Out:
# np.float64(1.469693845669907)

# %%
np.argsort(arr1)
# Out:
# array([2, 0, 1, 3, 4])

# %%
np.var(arr1)
# Out:
# np.float64(2.16)

# %%
np.sum(arr1)
# Out:
# np.int64(14)

# %%
np.prod(arr1)
# Out:
# np.int64(80)

# %%
np.median(arr1)
# Out:
# np.float64(2.0)

# %%
np.percentile(arr1,50)
# Out:
# np.float64(2.0)

# %%
np.argmax(arr1)
# Out:
# np.int64(4)

# %%
np.argmin(arr1)
# Out:
# np.int64(2)

# %%
np.max(arr1)
